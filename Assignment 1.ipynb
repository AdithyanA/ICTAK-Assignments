# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Reading dataset into python environment

# %%
cc = pd.read_excel(r"C:\Users\ethan\Downloads\iris.xls")

# %%
cc.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# ## Displaying the columns

# %%
cc.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ## Finding the mean of the values in each column

# %%
cc.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
column_mean = cc.columns[:-1]

# %%
cc[column_mean].head()
# Out:
#     SL   SW   PL   PW
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
cc[column_mean].mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
#  ## Checking for null values

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
cc[cc.columns].isnull().value_counts()
# Out:
# SL     SW     PL     PW     Classification
# False  False  False  False  False             150
# dtype: int64

# %% [markdown]
# ## Data Visualizations

# %%
cc.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
sns.countplot(data = cc, x='SL', hue='Classification')
# Out:
# <Axes: xlabel='SL', ylabel='count'>

# %%
ll = cc.groupby('Classification')['SL'].sum().reset_index()
plt.bar(ll['Classification'],ll['SL'])
# Out:
# <BarContainer object of 3 artists>

# %%
sns.scatterplot(x='SL', y='SW',hue='Classification', data=cc )
# Out:
# <Axes: xlabel='SL', ylabel='SW'>

# %%
sns.scatterplot(x='SL', y='PL',hue='Classification', data=cc )
# Out:
# <Axes: xlabel='SL', ylabel='PL'>

# %%
sns.scatterplot(x='PL', y='PW',hue='Classification', data=cc )
# Out:
# <Axes: xlabel='PL', ylabel='PW'>

# %% [markdown]
#  Got a couple of graph ideas but coudn't make it to wrokout. Got frustrated and the above codes are the ones that I borowed from Geek for Geeks' website.
#  (；′⌒`)
